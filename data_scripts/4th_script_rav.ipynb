# %%
import requests
import json
import time
import pandas as pd

# %%
url = f"https://api.ravelry.com/projects/search.json"
uid, pw = "read-0ea4f9f35434b031dbcf2acbe301c226", "tlSskeRXLNybZBFYzE2gZaAL7K2Fh/eXPnLuHly9"

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=2%7C1%7C0&photo=yes&status=finished&finished-in=1&country=united-states&sort=completed&view=thumbs
# happiness 0|1|2
# expected 47,463
# 17

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "0|1|2",
    "finished-in": "1",
    "status": "finished"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
        "page": 1,
        "page_size": 4999,
        "craft": "crochet",
        "photo": "yes",
        "country": "united-states",
        "happiness": "0|1|2",
        "finished-in": "1",
        "status": "finished"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 10
# Fetching page 1/10...
#   → 4999 records (total: 4999)
# Fetching page 2/10...
#   → 4999 records (total: 9998)
# Fetching page 3/10...
#   → 4999 records (total: 14997)
# Fetching page 4/10...
#   → 4999 records (total: 19996)
# Fetching page 5/10...
#   → 4999 records (total: 24995)
# Fetching page 6/10...
#   → 4999 records (total: 29994)
# Fetching page 7/10...
#   → 4999 records (total: 34993)
# Fetching page 8/10...
#   → 4999 records (total: 39992)
# Fetching page 9/10...
#   → 4999 records (total: 44991)
# Fetching page 10/10...
#   → 4999 records (total: 49990)
# Done. Total rows: 49990

# %%
df.to_csv("progress_save_df_17.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&meterage-in=600-750%7C750-900%7C900-1200%7C1200-1500%7C1500-1800%7C1800-2100%7C2100-%7C450-600%7C300-450%7C150-300&finished-in=1&country=united-states&sort=completed&view=thumbs
#96,554 matches

# 18

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "600-750|750-900|900-1200|1200-1500|1500-1800|1800-2100|2100-|450-600|300-450|150-300"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "600-750|750-900|900-1200|1200-1500|1500-1800|1800-2100|2100-|450-600|300-450|150-300"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 20
# Fetching page 1/20...
#   → 4999 records (total: 4999)
# Fetching page 2/20...
#   → 4999 records (total: 9998)
# Fetching page 3/20...
#   Empty response (status: 500), retrying in 60s...
#   → 4999 records (total: 14997)
# Fetching page 4/20...
#   → 4999 records (total: 19996)
# Fetching page 5/20...
#   → 4999 records (total: 24995)
# Fetching page 6/20...
#   → 4999 records (total: 29994)
# Fetching page 7/20...
#   → 4999 records (total: 34993)
# Fetching page 8/20...
#   → 4999 records (total: 39992)
# Fetching page 9/20...
#   → 4999 records (total: 44991)
# Fetching page 10/20...
#   → 4999 records (total: 49990)
# Fetching page 11/20...
#   → 4999 records (total: 54989)
# Fetching page 12/20...
#   → 4999 records (total: 59988)
# Fetching page 13/20...
#   → 4999 records (total: 64987)
# Fetching page 14/20...
#   → 4999 records (total: 69986)
# Fetching page 15/20...
#   → 4999 records (total: 74985)
# Fetching page 16/20...
# ...

# %%
df.to_csv("progress_save_df_18.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&finished-in=1&country=united-states&meterage-in=0-150&sort=completed&view=thumbs

#32,977 matches
#19

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "0-150"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "0-150"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 7
# Fetching page 1/7...
#   → 4999 records (total: 4999)
# Fetching page 2/7...
#   → 4999 records (total: 9998)
# Fetching page 3/7...
#   → 4999 records (total: 14997)
# Fetching page 4/7...
#   → 4999 records (total: 19996)
# Fetching page 5/7...
#   → 4999 records (total: 24995)
# Fetching page 6/7...
#   → 4999 records (total: 29994)
# Fetching page 7/7...
#   → 4999 records (total: 34993)
# Done. Total rows: 34993

# %%
df.to_csv("progress_save_df_19.csv")

# %%
# https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&meterage-in=-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500%2B-1500-1800%2B-1800-2100%2B-2100-&finished-in=1&country=united-states&language=en&sort=completed&view=thumbs
# 66,946 matches
#20
df = pd.DataFrame()

response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
    "language": "en"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
            "language": "en"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 14
# Fetching page 1/14...
#   → 4999 records (total: 4999)
# Fetching page 2/14...
#   → 4999 records (total: 9998)
# Fetching page 3/14...
#   → 4999 records (total: 14997)
# Fetching page 4/14...
#   → 4999 records (total: 19996)
# Fetching page 5/14...
#   → 4999 records (total: 24995)
# Fetching page 6/14...
#   → 4999 records (total: 29994)
# Fetching page 7/14...
#   → 4999 records (total: 34993)
# Fetching page 8/14...
#   → 4999 records (total: 39992)
# Fetching page 9/14...
#   → 4999 records (total: 44991)
# Fetching page 10/14...
#   → 4999 records (total: 49990)
# Fetching page 11/14...
#   → 4999 records (total: 54989)
# Fetching page 12/14...
#   Empty response (status: 500), retrying in 60s...
#   → 4999 records (total: 59988)
# Fetching page 13/14...
#   → 4999 records (total: 64987)
# Fetching page 14/14...
#   → 4999 records (total: 69986)
# Done. Total rows: 69986

# %%
df.to_csv("progress_save_df_20.csv")

# %%
# https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&meterage-in=-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500%2B-1500-1800%2B-1800-2100%2B-2100-&finished-in=1&colors=1%7C2%7C3%7C4%7C5%7C6&language=-en&country=united-states&sort=completed&view=thumbs
# 57,055 matches
#21
df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
    "language": "-en", 
    "colors": "1|2|3|4|5|6"

})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
            "language": "-en",
            "colors": "1|2|3|4|5|6"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 12
# Fetching page 1/12...
#   → 4999 records (total: 4999)
# Fetching page 2/12...
#   → 4999 records (total: 9998)
# Fetching page 3/12...
#   → 4999 records (total: 14997)
# Fetching page 4/12...
#   → 4999 records (total: 19996)
# Fetching page 5/12...
#   → 4999 records (total: 24995)
# Fetching page 6/12...
#   → 4999 records (total: 29994)
# Fetching page 7/12...
#   → 4999 records (total: 34993)
# Fetching page 8/12...
#   → 4999 records (total: 39992)
# Fetching page 9/12...
#   → 4999 records (total: 44991)
# Fetching page 10/12...
#   → 4999 records (total: 49990)
# Fetching page 11/12...
#   → 4999 records (total: 54989)
# Fetching page 12/12...
#   → 4999 records (total: 59988)
# Done. Total rows: 59988

# %%
df.to_csv("progress_save_df_21.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&meterage-in=-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500%2B-1500-1800%2B-1800-2100%2B-2100-&finished-in=1&colors=-1%2B-2%2B-3%2B-4%2B-5%2B-6&language=-en&country=united-states&has-notes=yes&sort=completed&view=thumbs
#70,211 matches
#22

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
    "language": "-en", 
    "colors": "-1+-2+-3+-4+-5+-6",
    "has-notes": "yes"
})

last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
            "language": "-en",
            "colors": "-1+-2+-3+-4+-5+-6",
            "has-notes": "yes"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 15
# Fetching page 1/15...
#   → 4999 records (total: 4999)
# Fetching page 2/15...
#   → 4999 records (total: 9998)
# Fetching page 3/15...
#   → 4999 records (total: 14997)
# Fetching page 4/15...
#   → 4999 records (total: 19996)
# Fetching page 5/15...
#   → 4999 records (total: 24995)
# Fetching page 6/15...
#   → 4999 records (total: 29994)
# Fetching page 7/15...
#   → 4999 records (total: 34993)
# Fetching page 8/15...
#   → 4999 records (total: 39992)
# Fetching page 9/15...
#   → 4999 records (total: 44991)
# Fetching page 10/15...
#   → 4999 records (total: 49990)
# Fetching page 11/15...
#   → 4999 records (total: 54989)
# Fetching page 12/15...
#   → 4999 records (total: 59988)
# Fetching page 13/15...
#   → 4999 records (total: 64987)
# Fetching page 14/15...
#   → 4999 records (total: 69986)
# Fetching page 15/15...
#   → 4999 records (total: 74985)
# Done. Total rows: 74985

# %%
df.to_csv("progress_save_df_22.csv")

# %%
# https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&meterage-in=-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500%2B-1500-1800%2B-1800-2100%2B-2100-&finished-in=1&colors=-1%2B-2%2B-3%2B-4%2B-5%2B-6&has-notes=no&language=-en&country=united-states&published=yes&sort=completed&view=thumbs
# 81,434 matches
#23

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
    "language": "-en", 
    "colors": "-1+-2+-3+-4+-5+-6",
    "has-notes": "no",
    "published": "yes"
})

last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
            "language": "-en",
            "colors": "-1+-2+-3+-4+-5+-6",
            "has-notes": "no",
            "published": "yes"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 17
# Fetching page 1/17...
#   → 4999 records (total: 4999)
# Fetching page 2/17...
#   → 4999 records (total: 9998)
# Fetching page 3/17...
#   → 4999 records (total: 14997)
# Fetching page 4/17...
#   → 4999 records (total: 19996)
# Fetching page 5/17...
#   → 4999 records (total: 24995)
# Fetching page 6/17...
#   → 4999 records (total: 29994)
# Fetching page 7/17...
#   → 4999 records (total: 34993)
# Fetching page 8/17...
#   → 4999 records (total: 39992)
# Fetching page 9/17...
#   → 4999 records (total: 44991)
# Fetching page 10/17...
#   → 4999 records (total: 49990)
# Fetching page 11/17...
#   → 4999 records (total: 54989)
# Fetching page 12/17...
#   → 4999 records (total: 59988)
# Fetching page 13/17...
#   → 4999 records (total: 64987)
# Fetching page 14/17...
#   → 4999 records (total: 69986)
# Fetching page 15/17...
#   → 4999 records (total: 74985)
# Fetching page 16/17...
#   → 4999 records (total: 79984)
# Fetching page 17/17...
# ...

# %%
df.to_csv("progress_save_df_23.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=-4%2B-3%2B-2%2B-1%2B-0&photo=yes&status=finished&published=no&meterage-in=-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500%2B-1500-1800%2B-1800-2100%2B-2100-&finished-in=1&colors=-1%2B-2%2B-3%2B-4%2B-5%2B-6&has-notes=no&language=-en&country=united-states&sort=completed&view=thumbs
#44,095 matches
#24

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "-4+-3+-2+-1+-0",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
    "language": "-en", 
    "colors": "-1+-2+-3+-4+-5+-6",
    "has-notes": "no",
    "published": "no"
})

last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": 1,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "-4+-3+-2+-1+-0",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500+-1500-1800+-1800-2100+-2100-",
            "language": "-en",
            "colors": "-1+-2+-3+-4+-5+-6",
            "has-notes": "no",
            "published": "no"
        })
        
        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 9
# Fetching page 1/9...
#   → 4999 records (total: 4999)
# Fetching page 2/9...
#   → 4999 records (total: 9998)
# Fetching page 3/9...
#   → 4999 records (total: 14997)
# Fetching page 4/9...
#   → 4999 records (total: 19996)
# Fetching page 5/9...
#   → 4999 records (total: 24995)
# Fetching page 6/9...
#   Empty response (status: 500), retrying in 60s...
#   → 4999 records (total: 29994)
# Fetching page 7/9...
#   → 4999 records (total: 34993)
# Fetching page 8/9...
#   → 4999 records (total: 39992)
# Fetching page 9/9...
#   → 4999 records (total: 44991)
# Done. Total rows: 44991

# %%
df.to_csv("progress_save_df_24.csv")
