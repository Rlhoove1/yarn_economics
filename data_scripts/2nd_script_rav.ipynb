# %%
import requests
import json
import time
import pandas as pd

# %%
url = f"https://api.ravelry.com/projects/search.json"
uid, pw = "read-0ea4f9f35434b031dbcf2acbe301c226", "tlSskeRXLNybZBFYzE2gZaAL7K2Fh/eXPnLuHly9"

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=5.0mm&finished-in=1&country=united-states&sort=completed&view=thumbs
# 93,147 matches
#not have meterage, and has 5.0mm
#6
df = pd.DataFrame()

# Prepqre
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "5.0mm"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "5.0mm"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 19
# Fetching page 1/19...
#   → 4999 records (total: 4999)
# Fetching page 2/19...
#   → 4999 records (total: 9998)
# Fetching page 3/19...
#   → 4999 records (total: 14997)
# Fetching page 4/19...
#   → 4999 records (total: 19996)
# Fetching page 5/19...
#   → 4999 records (total: 24995)
# Fetching page 6/19...
#   → 4999 records (total: 29994)
# Fetching page 7/19...
#   → 4999 records (total: 34993)
# Fetching page 8/19...
#   → 4999 records (total: 39992)
# Fetching page 9/19...
#   → 4999 records (total: 44991)
# Fetching page 10/19...
#   → 4999 records (total: 49990)
# Fetching page 11/19...
#   → 4999 records (total: 54989)
# Fetching page 12/19...
#   → 4999 records (total: 59988)
# Fetching page 13/19...
#   → 4999 records (total: 64987)
# Fetching page 14/19...
#   → 4999 records (total: 69986)
# Fetching page 15/19...
#   → 4999 records (total: 74985)
# Fetching page 16/19...
# <positron-console-cell-3>:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 79984)
# Fetching page 17/19...
#   → 4999 records (total: 84983)
# Fetching page 18/19...
#   → 4999 records (total: 89982)
# Fetching page 19/19...
#   → 2999 records (total: 92981)
# Done. Total rows: 92981

# %%
df.to_csv("progress_save_df_6.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B4.0mm&finished-in=1&country=united-states&sort=completed&view=thumbs
# "hooks": "-5.0mm+4.0mm" exclude 5.0mm, include 4.0mm
# 65,821 matches
#7
df = pd.DataFrame()

# Prepqre
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+4.0mm"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+4.0mm"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 14
# Fetching page 1/14...
#   → 4999 records (total: 4999)
# Fetching page 2/14...
#   → 4999 records (total: 9998)
# Fetching page 3/14...
#   → 4999 records (total: 14997)
# Fetching page 4/14...
#   → 4999 records (total: 19996)
# Fetching page 5/14...
# <positron-console-cell-5>:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 24995)
# Fetching page 6/14...
#   → 4999 records (total: 29994)
# Fetching page 7/14...
#   → 4999 records (total: 34993)
# Fetching page 8/14...
#   → 4999 records (total: 39992)
# Fetching page 9/14...
#   → 4999 records (total: 44991)
# Fetching page 10/14...
#   → 4999 records (total: 49990)
# Fetching page 11/14...
#   → 4999 records (total: 54989)
# Fetching page 12/14...
#   → 4999 records (total: 59988)
# Fetching page 13/14...
#   → 4999 records (total: 64987)
# Fetching page 14/14...
#   → 679 records (total: 65666)
# Done. Total rows: 65666

# %%
df.to_csv("progress_save_df_7.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&country=united-states&colors=1&sort=completed&view=thumbs
#  not  (5.0mm or 4.0mm), color =1 
# #74,039 matches
#8
df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "1"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "1"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 15
# Fetching page 1/15...
#   → 4999 records (total: 4999)
# Fetching page 2/15...
#   → 4999 records (total: 9998)
# Fetching page 3/15...
#   → 4999 records (total: 14997)
# Fetching page 4/15...
#   → 4999 records (total: 19996)
# Fetching page 5/15...
#   → 4999 records (total: 24995)
# Fetching page 6/15...
#   → 4999 records (total: 29994)
# Fetching page 7/15...
#   → 4999 records (total: 34993)
# Fetching page 8/15...
#   → 4999 records (total: 39992)
# Fetching page 9/15...
#   → 4999 records (total: 44991)
# Fetching page 10/15...
#   → 4999 records (total: 49990)
# Fetching page 11/15...
#   → 4999 records (total: 54989)
# Fetching page 12/15...
#   → 4999 records (total: 59988)
# Fetching page 13/15...
#   → 4999 records (total: 64987)
# Fetching page 14/15...
#   → 4999 records (total: 69986)
# Fetching page 15/15...
#   → 3918 records (total: 73904)
# Done. Total rows: 73904

# %%
df.to_csv("progress_save_df_8.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=2%7C3%7C4%7C5%7C6&country=united-states&sort=completed&view=thumbs
#  not  (5.0mm or 4.0mm), color =  "2|3|4|5|6"
# 49,331 matches
# 9

df = pd.DataFrame()

# Prepqre
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "2|3|4|5|6"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "2|3|4|5|6"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 10
# Fetching page 1/10...
#   → 4999 records (total: 4999)
# Fetching page 2/10...
#   → 4999 records (total: 9998)
# Fetching page 3/10...
#   → 4999 records (total: 14997)
# Fetching page 4/10...
#   → 4999 records (total: 19996)
# Fetching page 5/10...
#   → 4999 records (total: 24995)
# Fetching page 6/10...
#   → 4999 records (total: 29994)
# Fetching page 7/10...
#   → 4999 records (total: 34993)
# Fetching page 8/10...
# <positron-console-cell-9>:53: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 39992)
# Fetching page 9/10...
#   → 4999 records (total: 44991)
# Fetching page 10/10...
#   → 4266 records (total: 49257)
# Done. Total rows: 49257

# %%
df.to_csv("progress_save_df_9.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&country=united-states&weight=aran&sort=completed&view=thumbs
#
#63,332 matches
#10

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "aran"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "aran"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 13
# Fetching page 1/13...
#   → 4999 records (total: 4999)
# Fetching page 2/13...
#   → 4999 records (total: 9998)
# Fetching page 3/13...
#   → 4999 records (total: 14997)
# Fetching page 4/13...
#   → 4999 records (total: 19996)
# Fetching page 5/13...
# <positron-console-cell-11>:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 24995)
# Fetching page 6/13...
#   → 4999 records (total: 29994)
# Fetching page 7/13...
#   → 4999 records (total: 34993)
# Fetching page 8/13...
#   → 4999 records (total: 39992)
# Fetching page 9/13...
#   → 4999 records (total: 44991)
# Fetching page 10/13...
#   → 4999 records (total: 49990)
# Fetching page 11/13...
#   → 4999 records (total: 54989)
# Fetching page 12/13...
#   → 4999 records (total: 59988)
# Fetching page 13/13...
#   → 3251 records (total: 63239)
# Done. Total rows: 63239

# %%
df.to_csv("progress_save_df_10.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&weight=-aran&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&country=united-states&language=en&sort=completed&view=thumbs
# 87,199 matches
#11
df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "-aran",
    "language": "en"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "-aran",
            "language": "en"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 18
# Fetching page 1/18...
#   → 4999 records (total: 4999)
# Fetching page 2/18...
#   → 4999 records (total: 9998)
# Fetching page 3/18...
#   → 4999 records (total: 14997)
# Fetching page 4/18...
#   → 4999 records (total: 19996)
# Fetching page 5/18...
# <positron-console-cell-13>:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 24995)
# Fetching page 6/18...
#   → 4999 records (total: 29994)
# Fetching page 7/18...
#   → 4999 records (total: 34993)
# Fetching page 8/18...
#   → 4999 records (total: 39992)
# Fetching page 9/18...
#   → 4999 records (total: 44991)
# Fetching page 10/18...
#   → 4999 records (total: 49990)
# Fetching page 11/18...
#   → 4999 records (total: 54989)
# Fetching page 12/18...
#   → 4999 records (total: 59988)
# Fetching page 13/18...
#   → 4999 records (total: 64987)
# Fetching page 14/18...
#   → 4999 records (total: 69986)
# Fetching page 15/18...
#   → 4999 records (total: 74985)
# Fetching page 16/18...
#   → 4999 records (total: 79984)
# Fetching page 17/18...
#   → 4999 records (total: 84983)
# Fetching page 18/18...
#   → 1974 records (total: 86957)
# Done. Total rows: 86957

# %%
df.to_csv("progress_save_df_11.csv")

# %%
#https://www.ravelry.com/projects/search#craft=crochet&happiness=4&weight=-aran&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&language=-en&country=united-states&pc=accessories&sort=completed&view=thumbs
#63,782 matches
#12 

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "-aran",
    "language": "-en",
    "pc": "accessories"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "-aran",
            "language": "-en",
            "pc": "accessories"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 13
# Fetching page 1/13...
#   → 4999 records (total: 4999)
# Fetching page 2/13...
#   → 4999 records (total: 9998)
# Fetching page 3/13...
# <positron-console-cell-15>:58: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 14997)
# Fetching page 4/13...
#   → 4999 records (total: 19996)
# Fetching page 5/13...
#   → 4999 records (total: 24995)
# Fetching page 6/13...
#   → 4999 records (total: 29994)
# Fetching page 7/13...
#   → 4999 records (total: 34993)
# Fetching page 8/13...
#   → 4999 records (total: 39992)
# Fetching page 9/13...
#   → 4999 records (total: 44991)
# Fetching page 10/13...
#   → 4999 records (total: 49990)
# Fetching page 11/13...
#   → 4999 records (total: 54989)
# Fetching page 12/13...
#   → 4999 records (total: 59988)
# Fetching page 13/13...
#   → 3657 records (total: 63645)
# Done. Total rows: 63645

# %%
df.to_csv("progress_save_df_12.csv")

# %%
#https://www.ravelry.com/projects/search#pc=-accessories&craft=crochet&happiness=4&weight=-aran&photo=yes&status=finished&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&language=-en&country=united-states&color-family=White&sort=completed&view=thumbs
#
#2,398 matches
#13

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "-aran",
    "language": "-en",
    "pc": "-accessories",
    "color-family": "White"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "-aran",
            "language": "-en",
            "pc": "-accessories",
            "color-family": "White"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 1
# Fetching page 1/1...
#   → 2395 records (total: 2395)
# Done. Total rows: 2395

# %%
df.to_csv("progress_save_df_13.csv")

# %%
#https://www.ravelry.com/projects/search#pc=-accessories&craft=crochet&happiness=4&weight=-aran&color-family=-White&photo=yes&status=finished&published=no&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&language=-en&country=united-states&sort=completed&view=thumbs
#99,079 matches
#14

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "-aran",
    "language": "-en",
    "pc": "-accessories",
    "color-family": "-White",
    "published": "no"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "-aran",
            "language": "-en",
            "pc": "-accessories",
            "color-family": "-White",
            "published": "no"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 20
# Fetching page 1/20...
#   → 4999 records (total: 4999)
# Fetching page 2/20...
#   → 4999 records (total: 9998)
# Fetching page 3/20...
# <positron-console-cell-19>:62: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 14997)
# Fetching page 4/20...
#   → 4999 records (total: 19996)
# Fetching page 5/20...
#   → 4999 records (total: 24995)
# Fetching page 6/20...
#   → 4999 records (total: 29994)
# Fetching page 7/20...
#   → 4999 records (total: 34993)
# Fetching page 8/20...
#   → 4999 records (total: 39992)
# Fetching page 9/20...
#   → 4999 records (total: 44991)
# Fetching page 10/20...
#   → 4999 records (total: 49990)
# Fetching page 11/20...
#   → 4999 records (total: 54989)
# Fetching page 12/20...
#   → 4999 records (total: 59988)
# Fetching page 13/20...
#   → 4999 records (total: 64987)
# Fetching page 14/20...
#   → 4999 records (total: 69986)
# Fetching page 15/20...
#   → 4999 records (total: 74985)
# Fetching page 16/20...
#   → 4999 records (total: 79984)
# Fetching page 17/20...
#   → 4999 records (total: 84983)
# Fetching page 18/20...
#   → 4999 records (total: 89982)
# Fetching page 19/20...
#   → 4999 records (total: 94981)
# Fetching page 20/20...
#   → 4088 records (total: 99069)
# Done. Total rows: 99069

# %%
df.to_csv("progress_save_df_14.csv")

# %%
#https://www.ravelry.com/projects/search#pc=-accessories&craft=crochet&happiness=4&weight=-aran&color-family=-White&photo=yes&status=finished&published=yes&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&language=-en&country=united-states&has-notes=yes&sort=completed&view=thumbs
#
#35,842 matches
#15


df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "-aran",
    "language": "-en",
    "pc": "-accessories",
    "color-family": "-White",
    "published": "yes",
    "has-notes": "yes"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "-aran",
            "language": "-en",
            "pc": "-accessories",
            "color-family": "-White",
            "published": "no",
            "has-notes": "yes"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 8
# Fetching page 1/8...
#   → 4999 records (total: 4999)
# Fetching page 2/8...
#   → 4999 records (total: 9998)
# Fetching page 3/8...
# <positron-console-cell-21>:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 14997)
# Fetching page 4/8...
#   → 4999 records (total: 19996)
# Fetching page 5/8...
#   → 4999 records (total: 24995)
# Fetching page 6/8...
#   → 4999 records (total: 29994)
# Fetching page 7/8...
#   → 4999 records (total: 34993)
# Fetching page 8/8...
#   → 4999 records (total: 39992)
# Done. Total rows: 39992

# %%
df.to_csv("progress_save_df_15.csv")

# %%
#https://www.ravelry.com/projects/search#pc=-accessories&craft=crochet&happiness=4&weight=-aran&color-family=-White&photo=yes&status=finished&published=yes&meterage-in=-1500-1800%2B-1800-2100%2B-2100-%2B-0-150%2B-150-300%2B-300-450%2B-450-600%2B-600-750%2B-750-900%2B-900-1200%2B-1200-1500&hooks=-5.0mm%2B-4.0mm&finished-in=1&colors=-2%2B-3%2B-4%2B-5%2B-6%2B-1&has-notes=no&language=-en&country=united-states&sort=completed&view=thumbs
#
#82,042 matches
#16

df = pd.DataFrame()

# Prepare
response = requests.get(url, auth=(uid, pw), params={
    "page": 1,
    "page_size": 4999,
    "craft": "crochet",
    "photo": "yes",
    "country": "united-states",
    "happiness": "4",
    "finished-in": "1",
    "status": "finished",
    "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
    "hooks": "-5.0mm+-4.0mm",
    "colors": "-2+-3+-4+-5+-6+-1",
    "weight": "-aran",
    "language": "-en",
    "pc": "-accessories",
    "color-family": "-White",
    "published": "yes",
    "has-notes": "no"
})
last_page = response.json()['paginator']['last_page']
print(f"Total pages: {last_page}")

for page in range(1, last_page + 1):
    print(f"Fetching page {page}/{last_page}...")

    retry_delay = 60
    while True:
        response = requests.get(url, auth=(uid, pw), params={
            "page": page,
            "page_size": 4999,
            "craft": "crochet",
            "photo": "yes",
            "country": "united-states",
            "happiness": "4",
            "finished-in": "1",
            "status": "finished",
            "meterage-in": "-1500-1800+-1800-2100+-2100-+-0-150+-150-300+-300-450+-450-600+-600-750+-750-900+-900-1200+-1200-1500",
            "hooks": "-5.0mm+-4.0mm",
            "colors": "-2+-3+-4+-5+-6+-1",
            "weight": "-aran",
            "language": "-en",
            "pc": "-accessories",
            "color-family": "-White",
            "published": "no",
            "has-notes": "no"
        })

        try:
            responselist = response.json()
            break
        except requests.exceptions.JSONDecodeError:
            print(f"  Empty response (status: {response.status_code}), retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retry_delay = min(retry_delay * 2, 300)

    df_page = pd.json_normalize(responselist['projects'])
    df = pd.concat([df, df_page], ignore_index=True)
    print(f"  → {len(df_page)} records (total: {len(df)})")

    if page < last_page:
        time.sleep(60)

print(f"Done. Total rows: {len(df)}")
# Out:
# Total pages: 17
# Fetching page 1/17...
#   → 4999 records (total: 4999)
# Fetching page 2/17...
# <positron-console-cell-23>:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   → 4999 records (total: 9998)
# Fetching page 3/17...
#   → 4999 records (total: 14997)
# Fetching page 4/17...
#   → 4999 records (total: 19996)
# Fetching page 5/17...
#   → 4999 records (total: 24995)
# Fetching page 6/17...
#   → 4999 records (total: 29994)
# Fetching page 7/17...
#   → 4999 records (total: 34993)
# Fetching page 8/17...
#   → 4999 records (total: 39992)
# Fetching page 9/17...
#   → 4999 records (total: 44991)
# Fetching page 10/17...
#   → 584 records (total: 45575)
# Fetching page 11/17...
#   → 0 records (total: 45575)
# Fetching page 12/17...
#   → 0 records (total: 45575)
# Fetching page 13/17...
#   → 0 records (total: 45575)
# Fetching page 14/17...
#   → 0 records (total: 45575)
# Fetching page 15/17...
#   → 0 records (total: 45575)
# Fetching page 16/17...
#   → 0 records (total: 45575)
# Fetching page 17/17...
#   → 0 records (total: 45575)
# Done. Total rows: 45575

# %%
df.to_csv("progress_save_df_16.csv")
