# %%
import requests
import json
import time
import pandas as pd

# %%
df_6=pd.read_csv("/Users/rorihoover/progress_save_df_6.csv")
df_6= df_6.drop(df_6.columns[0], axis=1)
print("df_6 expected, 93,147 matches")
print(len(df_6))

df_17=pd.read_csv("/Users/rorihoover/progress_save_df_17.csv")
df_17 = df_17.drop(df_17.columns[0], axis=1)
print("df_17 expected, 47,463 matches")
print(len(df_17))

df_18=pd.read_csv("/Users/rorihoover/progress_save_df_18.csv")
df_18 = df_18.drop(df_18.columns[0], axis=1)
print("df_18 expected, 96,554 matches")
print(len(df_18))

df_19=pd.read_csv("/Users/rorihoover/progress_save_df_19.csv")
df_19 = df_19.drop(df_19.columns[0], axis=1)
print("df_19 expected, 32,977 matches")
print(len(df_19))

df_20=pd.read_csv("/Users/rorihoover/progress_save_df_20.csv")
df_20 = df_20.drop(df_20.columns[0], axis=1)
print("df_20 expected, 66,946 matches")
print(len(df_20))

df_21=pd.read_csv("/Users/rorihoover/progress_save_df_21.csv")
df_21 = df_21.drop(df_21.columns[0], axis=1)
print("df_21 expected, 57,055 matches")
print(len(df_21))

df_22=pd.read_csv("/Users/rorihoover/progress_save_df_22.csv")
df_22 = df_22.drop(df_22.columns[0], axis=1)
print("df_22 expected, 70,211 matches")
print(len(df_22))

df_23=pd.read_csv("/Users/rorihoover/progress_save_df_23.csv")
df_23 = df_23.drop(df_23.columns[0], axis=1)
print("df_23 expected, 81,434 matches")
print(len(df_23))

df_24=pd.read_csv("/Users/rorihoover/progress_save_df_24.csv")
df_24 = df_24.drop(df_24.columns[0], axis=1)
print("df_24 expected, 44,095 matches")
print(len(df_24))
# Out:
# df_6 expected, 93,147 matches
# 92980
# df_17 expected, 47,463 matches
# 49990
# df_18 expected, 96,554 matches
# 99980
# df_19 expected, 32,977 matches
# 34993
# df_20 expected, 66,946 matches
# 69986
# df_21 expected, 57,055 matches
# 59988
# df_22 expected, 70,211 matches
# 74985
# df_23 expected, 81,434 matches
# 84983
# df_24 expected, 44,095 matches
# 44991

# %%
df = pd.read_csv("progress_save_589699.csv")
df = df.drop(df.columns[0], axis=1)
len(df)
# Out:
# 589699

# %%
df_1 = pd.read_csv("frozen_progress_save_969459.csv")
# Out:
# <positron-console-cell-6>:1: DtypeWarning: Columns (41,42,43,44,45,46,47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df = pd.concat([df_6, df], ignore_index=True)
df = pd.concat([df, df_17], ignore_index=True)
df = pd.concat([df, df_18], ignore_index=True)
df = pd.concat([df, df_19], ignore_index=True)
df = pd.concat([df, df_20], ignore_index=True)
df = pd.concat([df, df_21], ignore_index=True)
df = pd.concat([df, df_22], ignore_index=True)
df = pd.concat([df, df_23], ignore_index=True)
df = pd.concat([df, df_24], ignore_index=True)

# %%
len(df)
# Out:
# 1202575

# %%
df = pd.concat([df, df_1], ignore_index=True)
len(df)
# Out:
# 2172034

# %%
df.to_csv("final_data.csv")

# %%
df = pd.read_csv("final_data.csv")
# Out:
# <positron-console-cell-3>:1: DtypeWarning: Columns (41,42,43,44,45,46,47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
print((df['id'] == 38461166).sum())
# Out:
# 0

# %%
df['id'].head()
# Out:
# 0    35546867
# 1    21979854
# 2    17948727
# 3    26559769
# 4    14921145
# Name: id, dtype: int64

# %%
a=pd.read_csv("/Users/rorihoover/Downloads/US_crochet_no_photo_finished_127674.csv")
b=pd.read_csv("/Users/rorihoover/Downloads/progress_save_2025_2026_108315.csv")

# %%
b = b.drop(b.columns[0], axis=1)

# %%
b['id'].head()
# Out:
# 0    38461166
# 1    38012743
# 2    38778711
# 3    38288488
# 4    38364039
# Name: id, dtype: int64

# %%
a['id'].head()
# Out:
# 0    38347818
# 1    38181472
# 2    38013656
# 3    38391539
# 4    37949438
# Name: id, dtype: int64

# %%
df = pd.concat([df, b], ignore_index=True)

# %%
df.to_csv("fixed_final_data.csv")
